# %% [markdown]
# # Game Theory
#
# ### Entering the market or not

# %%
from tabulate import tabulate
import numpy as np
from colorama import Fore, Back, Style
import time
# from matplotlib import pyplot as plt
# from matplotlib import image as mpimg

# %%
print(Fore.BLACK + Back.CYAN + """\033[1mYou and your friends decide to create a start-up called 'RoBrain'. 
Your company plans to create humanoid robots. But before you start production or any other activity, 
you need to decide does it make sense to enter the market, as there is already a huge and prosperous 
company Boston Dynamics(BD).

Therefore, you decided to generate a game with possible outcomes:
The reaction of the bigger market player on your entrance the market and your utility from that. 
Or is it better to stay out of the market?

You studied pretty hard at your university, so you can somehow predict the reaction
from BD and utility of each player. Moreover, when you decide to go second, you put yourself in BD "shoes"
and decide what you would have done in their place.

This code generates possible outcomes and utility results for different strategies.
As this is the game of reactions on the different actions of the players, there is a 
specific order of who goes first.\033[0m""")

print('\nThe table should be read like this:')

table0 = [['Player 1\Player 2', 'Fight', 'No'],
         ['Enter market', '[U1, U2]', '[U1, U2]'],
         ['Out', '[U1, U2]', '[U1, U2]']]

print(tabulate(table0, headers='firstrow', tablefmt='fancy_grid'), '\n', sep = '\n')
print(Style.RESET_ALL)

print(Fore.BLUE + "The outcomes of the generation looks like this:")
print(Style.RESET_ALL)

#Calculate the outcomes for the game by randomizing in :
rand_res_1 = np.random.randint(-4,-1)
rand_res_2 = np.random.randint(-2,0)
rand_res_3 = np.random.randint(3,10)
rand_res_4 = np.random.randint(3,7)
rand_res_5 = 0
rand_res_6 = np.random.randint(13,15)
rand_res_7 = 0
rand_res_8 = np.random.randint(14,18)

results_dict = {"Enter market":[[rand_res_1, rand_res_2],[rand_res_3, rand_res_4]],
               "Out":[[rand_res_5, rand_res_6], [rand_res_7, rand_res_8]]}



#Building a table  
table = [['Player 1\Player 2', 'Fight', 'No'],
         ['Enter market', [rand_res_1, rand_res_2], [rand_res_3, rand_res_4]],
         ['Out', [rand_res_5, rand_res_6], [rand_res_7, rand_res_8]]]

print(tabulate(table, headers='firstrow', tablefmt='fancy_grid'), '\n', sep = '\n')



#-------------------------------------------------------
#Addition of the picture to the game. Due to the submittion only in ipynb format, not zip format,
#picture is excluded from the final game.
# plt.title("Play with me")
# plt.xlabel("You")
# plt.ylabel("Will") 
# image = mpimg.imread("Saw_film.jpg")
# plt.imshow(image)
# plt.show()
#-------------------------------------------------------

#Asking user for the willingness to play the game
play_yn = input('Do you want to play the game with me?(Y/N) ')



#React based on the user's answer. Takes either first letter of 'Yes'/'No' or full word.
if play_yn.capitalize() == 'Y' or play_yn.lower() == 'yes':
    print(Fore.BLUE + '-Nice! Let\'s play!')
    print(Style.RESET_ALL)
    play_yn_1 = 1
    
elif play_yn.capitalize() == 'N' or play_yn.lower() == 'no':
    print(Fore.BLUE + '-That\'s sad. Then I\'ll play with myself')
    print(Style.RESET_ALL)
    play_yn_1 = 0

#Reaction of the program in case user puts something different from Y/N
else:
    while play_yn.capitalize() != 'Y' or play_yn.lower() != 'yes' or play_yn != 'N' or play_yn.lower() != 'no':
            print(Fore.RED + "-Sorry, I don't understand. Please answer 'Y' or 'N'")
            print(Style.RESET_ALL)
            play_yn = input('Do you want to play? ')
            if play_yn.capitalize() == 'Y' or play_yn.lower() == 'yes':
                print(Fore.BLUE + '-Nice! Let\'s play!')
                print(Style.RESET_ALL)
                play_yn_1 = 1
                break
                
            elif play_yn.capitalize() == 'N' or play_yn.lower() == 'no':
                print(Fore.BLUE + '-That\'s sad. Then I\'ll play with myself')
                print(Style.RESET_ALL)
                play_yn_1 = 0
                break

                
#If the player decides to play. Ask him/her if they want to go first.
if play_yn_1 == 1:
    #Asking user for the willingness to play first
    first_yn = input('Do you want to make the move first?(Y/N) ')

    #React based on the user's answer
    if first_yn.capitalize() == 'Y' or first_yn.lower() == 'yes':
        print(Fore.BLUE + '-Good luck!')
        print(Style.RESET_ALL)
        pl_first = 1

    elif first_yn.capitalize() == 'N' or first_yn.lower() == 'no':
        print(Fore.BLUE + '-Ok. Then I\'ll go first')
        print(Style.RESET_ALL)
        pl_first = 0

    #Continue asking in case if the user puts something different from the asked input until the answer is given.
    #Proceed accordingly
    else:
        while first_yn.capitalize() != 'Y' or first_yn.lower() != 'yes' or first_yn != 'N' or first_yn.lower() != 'no':
                print(Fore.RED + "Sorry, I don\'t understand. Please answer \'Y\' or \'N\'")
                print(Style.RESET_ALL)
                first_yn = input('Do you want to move first? ')
                
                if first_yn.capitalize() == 'Y' or first_yn.lower() == 'yes':
                    print(Fore.BLUE + '-Ok, it took long, but no worries. Go first.\nGood luck.')
                    pl_first = 1
                    print(Style.RESET_ALL)
                    break
                    
                elif first_yn.capitalize() == 'N' or first_yn.lower() == 'no':
                    print(Fore.BLUE + '-Ok, it took long, but no worries. Good luck to me then.')
                    pl_first = 0
                    print(Style.RESET_ALL)
                    break
    
    
#If the player is playing and player decided to go first.
if play_yn_1 == 1 and pl_first == 1:
    print('Now game looks like this:')
    table2 = [['You\Boston Dynamics', 'Fight', 'No'],
         ['Enter market', [rand_res_1, rand_res_2], [rand_res_3, rand_res_4]],
         ['Out', [rand_res_5, rand_res_6], [rand_res_7, rand_res_8]]]
    print(tabulate(table2, headers='firstrow', tablefmt='fancy_grid'), '\n', sep = '\n')

    print(Fore.GREEN + """Now you need to make a decision: Enter the market\033[1m(enter)\033[0m""" + Fore.GREEN + 
          """/stay out of the market\033[1m(out)\033[0m."""
            +Back.WHITE + """\nUtility from each action can be found higher.""")
    print(Style.RESET_ALL)
    fin_choice_pl = input('What is your decision? ')
    
    #If player decides to enter the market. Comparing the utility results to each other and giving the answer
    #based on the higher utility
    if fin_choice_pl.lower() == 'enter':
        if rand_res_2 < rand_res_4:
            print('Your opponent chose: ' + Fore.RED + 'Not to fight')
            print(Style.RESET_ALL)
            print('Final result:' + Fore.RED + f"""\033[1mEnter the market. No fighting.\033[0m 
                Utility:\t{results_dict['Enter market'][1]}
                This result is \033[1mNash Equilibrium.\033[0m""")
            if rand_res_3 < rand_res_4:
                print('BD has higher utility. \033[1mBD wins\033[0m.')
            elif rand_res_3 > rand_res_4:
                print('You have higher utility. \033[1mYou win\033[0m.')
            else:
                print("Utility is equal. \033[1mIt's a tie\033[0m.")
            
        elif rand_res_2 > rand_res_4:
            print('Your opponent chose: ' + Fore.RED + 'To fight')
            print(Style.RESET_ALL)
            print('Final result: ' + Fore.RED + f"""\033[1mEnter the market. Fighting.\033[0m
                Utility:\t{results_dict['Enter market'][0]}
                This result is \033[1mnot a Nash Equilibrium.\033[0m""")
            if rand_res_1 < rand_res_2:
                print('BD has higher utility. \033[1mBD wins\033[0m.')
            elif rand_res_1 > rand_res_2:
                print('You have higher utility. \033[1mYou win\033[0m.')
            else:
                print("Utility is equal. \033[1mIt's a tie\033[0m.")
       
        #In case if the utility values are equal. Continuing with randomization for the final decision as
        #the player is indifferent between the strategies (they give the same utility)
        else:
            print('The opponent is indefferent between strategies, so it\'ll be chosen randomly')
            rand_choice_1 = np.random.randint(0,2)
            if rand_choice_1 == 0:
                print('Your opponent chose: ' + Fore.RED + 'Not to fight')
                print(Style.RESET_ALL)
                print('Final result: ' + Fore.RED + f"""\033[1mEnter the market. No fighting.\033[0m
                    Utility:\t{results_dict['Enter market'][1]}
                    This result is \033[1mNash Equilibrium.\033[0m""")
                if rand_res_3 < rand_res_4:
                    print('BD has higher utility. \033[1mBD wins\033[0m.')
                elif rand_res_3 > rand_res_4:
                    print('You have higher utility. \033[1mYou win\033[0m.')
                else:
                    print("Utility is equal. \033[1mIt's a tie\033[0m.")
                
            else:
                print('Your opponent chose: ' + Fore.RED + 'To fight')
                print(Style.RESET_ALL)
                print('Final result: ' + Fore.RED + f"""\033[1mEnter the market. Fighting.\033[0m
                    Utility:\t{results_dict['Enter market'][0]}
                    This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                if rand_res_1 < rand_res_2:
                    print('BD has higher utility. \033[1mBD wins\033[0m.')
                elif rand_res_1 > rand_res_2:
                    print('You have higher utility. \033[1mYou win\033[0m.')
                else:
                    print("Utility is equal. \033[1mIt's a tie\033[0m.")
            
            
    #If the player decides to stay out of the market. Comparing the utility results to each other and giving the answer
    #based on the higher utility
    elif fin_choice_pl.lower() == 'out':
        if  rand_res_6 < rand_res_8:
            print('Your opponent chose: ' + Fore.RED + 'Not to fight')
            print(Style.RESET_ALL)
            print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. No fighting.\033[0m
                  Utility:\t{results_dict['Out'][1]}
                  This result is \033[1mnot a Nash Equilibrium.\033[0m""")
            print(Fore.GREEN + 'But your opponent has the highest utility. It is very happy! :) ')
            print(Style.RESET_ALL)
            if rand_res_7 < rand_res_8:
                print('BD has higher utility. \033[1mBD wins\033[0m.')
            elif rand_res_7 > rand_res_8:
                print('You have higher utility. \033[1mYou win\033[0m.')
            else:
                print("Utility is equal. \033[1mIt's a tie\033[0m.")
            
        elif rand_res_6 > rand_res_8:
            print('Your opponent chose: ' + Fore.RED + 'To fight')
            print(Style.RESET_ALL)
            print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. Fighting.\033[0m
                Utility:\t{results_dict['Out'][0]}
                This result is \033[1mnot a Nash Equilibrium.\033[0m""")
            if rand_res_5 < rand_res_6:
                print('BD has higher utility. \033[1mBD wins\033[0m.')
            elif rand_res_5 > rand_res_6:
                print('You have higher utility. \033[1mYou win\033[0m.')
            else:
                print("Utility is equal. \033[1mIt's a tie\033[0m.")
            
        #In case if the utility values are equal. Continuing with randomization for the final decision as
        #the player is indifferent between the strategies (they give the same utility)
        else:
            print('The opponent is indefferent between strategies, so it\'ll be chosen randomly')
            rand_choice_2 = np.random.randint(0,2)
            if rand_choice_2 == 0:
                print('Your opponent chose: ' + Fore.RED + 'Not to fight')
                print(Style.RESET_ALL)
                print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. No fighting.\033[0m
                    Utility:\t{results_dict['Out'][1]}
                    This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                print(Fore.GREEN + 'But your opponent has the highest utility. It is very happy! :) ')
                print(Style.RESET_ALL)
                if rand_res_7 < rand_res_8:
                    print('BD has higher utility. \033[1mBD wins\033[0m.')
                elif rand_res_7 > rand_res_8:
                    print('You have higher utility. \033[1mYou win\033[0m.')
                else:
                    print("Utility is equal. \033[1mIt's a tie\033[0m.")
                
            else:
                print('Your opponent chose: ' + Fore.RED + 'To fight')
                print(Style.RESET_ALL)
                print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. Fighting.\033[0m
                    Utility:\t{results_dict['Out'][0]}
                    This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                if rand_res_5 < rand_res_6:
                    print('BD has higher utility. \033[1mBD wins\033[0m.')
                elif rand_res_5 > rand_res_6:
                    print('You have higher utility. \033[1mYou win\033[0m.')
                else:
                    print("Utility is equal. \033[1mIt's a tie\033[0m.")
     
    
    #If player didn't enter the decision from the start: continue asking until receiving understandable input.
    #Proceed accordingly with the decision.
    else:
        while fin_choice_pl.capitalize() != 'Enter' or fin_choice_pl.capitalize() != 'Out':
            print(Fore.RED + "Sorry, I don't understand. Please answer 'Enter' or 'Out'")
            print(Style.RESET_ALL)
            fin_choice_pl = input('What is your decision? ')
            if fin_choice_pl.capitalize() == 'Enter':
                if rand_res_2 < rand_res_4:
                    print('Your opponent chose: ' + Fore.RED + 'Not to fight')
                    print(Style.RESET_ALL)
                    print('Final result:' + Fore.RED + f"""\033[1mEnter the market. No fighting.\033[0m 
                        Utility:\t{results_dict['Enter market'][1]}
                        This result is \033[1mNash Equilibrium.\033[0m""")
                    if rand_res_3 < rand_res_4:
                        print('BD has higher utility. \033[1mBD wins\033[0m.')
                    elif rand_res_3 > rand_res_4:
                        print('You have higher utility. \033[1mYou win\033[0m.')
                    else:
                        print("Utility is equal. \033[1mIt's a tie\033[0m.")
                    break
                    
                elif rand_res_2 > rand_res_4:
                    print('Your opponent chose: ' + Fore.RED + 'To fight')
                    print(Style.RESET_ALL)
                    print('Final result: ' + Fore.RED + f"""\033[1mEnter the market. Fighting.\033[0m
                        Utility:\t{results_dict['Enter market'][0]}
                        This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                    if rand_res_1 < rand_res_2:
                        print('BD has higher utility. \033[1mBD wins\033[0m.')
                    elif rand_res_1 > rand_res_2:
                        print('You have higher utility. \033[1mYou win\033[0m.')
                    else:
                        print("Utility is equal. \033[1mIt's a tie\033[0m.")
                    break
                    
                else:
                    print('The opponent is indefferent between strategies, so it\'ll be chosen randomly')
                    rand_choice_3 = np.random.randint(0,2)
                    if rand_choice_3 == 0:
                        print('Your opponent chose: ' + Fore.RED + 'Not to fight')
                        print(Style.RESET_ALL)
                        print('Final result:' + Fore.RED + f"""\033[1mEnter the market. No fighting.\033[0m 
                            Utility:\t{results_dict['Enter market'][1]}
                            This result is \033[1mNash Equilibrium.\033[0m""")
                        if rand_res_3 < rand_res_4:
                            print('BD has higher utility. \033[1mBD wins\033[0m.')
                        elif rand_res_3 > rand_res_4:
                            print('You have higher utility. \033[1mYou win\033[0m.')
                        else:
                            print("Utility is equal. \033[1mIt's a tie\033[0m.")
                        break
                        
                    else:
                        print('Your opponent chose: ' + Fore.RED + 'To fight')
                        print(Style.RESET_ALL)
                        print('Final result: ' + Fore.RED + f"""\033[1mEnter the market. Fighting.\033[0m
                            Utility:\t{results_dict['Enter market'][0]}
                            This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                        if rand_res_1 < rand_res_2:
                            print('BD has higher utility. \033[1mBD wins\033[0m.')
                        elif rand_res_1 > rand_res_2:
                            print('You have higher utility. \033[1mYou win\033[0m.')
                        else:
                            print("Utility is equal. \033[1mIt's a tie\033[0m.")
                        break
                        

        
            elif fin_choice_pl.capitalize() == 'Out':
                if  rand_res_6 < rand_res_8:
                    print('Your opponent chose: ' + Fore.RED + 'Not to fight')
                    print(Style.RESET_ALL)
                    print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. No fighting.\033[0m
                          Utility:\t{results_dict['Out'][1]}
                          This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                    print('But your opponent has the highest utility. It is very happy! :) ')
                    if rand_res_7 < rand_res_8:
                        print('BD has higher utility. \033[1mBD wins\033[0m.')
                    elif rand_res_7 > rand_res_8:
                        print('You have higher utility. \033[1mYou win\033[0m.')
                    else:
                        print("Utility is equal. \033[1mIt's a tie\033[0m.")
                    break
                    
                elif rand_res_6 > rand_res_8:
                    print('Your opponent chose: ' + Fore.RED + 'To fight')
                    print(Style.RESET_ALL)
                    print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. Fighting.\033[0m
                        Utility:\t{results_dict['Out'][0]}
                        This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                    if rand_res_5 < rand_res_6:
                        print('BD has higher utility. \033[1mBD wins\033[0m.')
                    elif rand_res_5 > rand_res_6:
                        print('You have higher utility. \033[1mYou win\033[0m.')
                    else:
                        print("Utility is equal. \033[1mIt's a tie\033[0m.")
                    break
                    
                else:
                    print('The opponent is indefferent between strategies, so it\'ll be chosen randomly')
                    rand_choice_2 = np.random.randint(0,2)
                    if rand_choice_2 == 0:
                        print('Your opponent chose: ' + Fore.RED + 'Not to fight')
                        print(Style.RESET_ALL)
                        print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. No fighting.\033[0m
                            Utility:\t{results_dict['Out'][1]}
                            This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                        if rand_res_7 < rand_res_8:
                            print('BD has higher utility. \033[1mBD wins\033[0m.')
                        elif rand_res_7 > rand_res_8:
                            print('You have higher utility. \033[1mYou win\033[0m.')
                        else:
                            print("Utility is equal. \033[1mIt's a tie\033[0m.")
                        break
                        
                    else:
                        print('Your opponent chose: ' + Fore.RED + 'To fight')
                        print(Style.RESET_ALL)
                        print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. Fighting.\033[0m
                            Utility:\t{results_dict['Out'][0]}
                            This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                        if rand_res_5 < rand_res_6:
                            print('BD has higher utility. \033[1mBD wins\033[0m.')
                        elif rand_res_5 > rand_res_6:
                            print('You have higher utility. \033[1mYou win\033[0m.')
                        else:
                            print("Utility is equal. \033[1mIt's a tie\033[0m.")
                        break
                        
                        

#If the user is playing, but decides to be second. Randomize decision for the first player.
if play_yn_1 == 1 and pl_first == 0:
    
    print('Now game looks like this:')
    table3 = [['Boston Dynamics\You', 'Fight', 'No'],
         ['Enter market', [rand_res_1, rand_res_2], [rand_res_3, rand_res_4]],
         ['Out', [rand_res_5, rand_res_6], [rand_res_7, rand_res_8]]]
    print(tabulate(table3, headers='firstrow', tablefmt='fancy_grid'), '\n', sep = '\n')
    
    rand_choice_3 = np.random.randint(0,2)
    if rand_choice_3 == 0:
        print('Your opponent chose to ' + Fore.BLUE + '\033[1menter the market\033[0m.')
        comp_choice = 'enter'
        
    else:
        print('Your opponent chose to ' + Fore.BLUE + '\033[1mstay out of the market\033[0m.')
        comp_choice = 'out'
    
    #Asking a player for the decision. Reacting accordingly to the decisions of both players.
    fin_choice_pl = str(input('What is your decision?' + Fore.GREEN + ' Fight or no? '))
    if fin_choice_pl.lower() == 'fight' and comp_choice == 'enter':
        print('Final result: ' + Fore.RED + f"""\033[1mEnter the market. Fighting.\033[0m 
                Utility:\t{results_dict['Enter market'][0]}
                This result is \033[1mnot a Nash Equilibrium.\033[0m""")
        if rand_res_1 < rand_res_2:
            print('You have higher utility. \033[1mYou win\033[0m.')
        elif rand_res_1 > rand_res_2:
            print('BD has higher utility. \033[1mBD wins\033[0m.')
        else:
            print("Utility is equal. \033[1mIt's a tie\033[0m.")
        
    elif fin_choice_pl.lower() == 'no' and comp_choice == 'enter':
        print('Final result: ' + Fore.RED + f"""\033[1mEnter the market. No fighting.\033[0m 
                Utility:\t{results_dict['Enter market'][1]}
                This result is \033[1mNash Equilibrium.\033[0m""")
        if rand_res_3 < rand_res_4:
            print('You have higher utility. \033[1mYou win\033[0m.')
        elif rand_res_3 > rand_res_4:
            print('BD has higher utility. \033[1mBD wins\033[0m.')
        else:
            print("Utility is equal. \033[1mIt's a tie\033[0m.")
        
    elif fin_choice_pl.lower() == 'fight' and comp_choice == 'out':
        print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. Fighting.\033[0m 
                Utility:\t{results_dict['Out'][0]}
                This result is \033[1mnot a Nash Equilibrium.\033[0m""")
        if rand_res_5 < rand_res_6:
            print('You have higher utility. \033[1mYou win\033[0m.')
        elif rand_res_5 > rand_res_6:
            print('BD has higher utility. \033[1mBD wins\033[0m.')
        else:
            print("Utility is equal. \033[1mIt's a tie\033[0m.")
        
    elif fin_choice_pl.lower() == 'no' and comp_choice == 'out':
        print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. No fighting.\033[0m 
                Utility:\t{results_dict['Out'][1]}
                This result is \033[1mnot a Nash Equilibrium.\033[0m""")
        print(Fore.GREEN + 'But you have the highest utility. You should be very happy! Congratulations! :) ')
        print(Style.RESET_ALL)
        if rand_res_7 < rand_res_8:
            print('You have higher utility. \033[1mYou win\033[0m.')
        elif rand_res_7 > rand_res_8:
            print('BD has higher utility. \033[1mBD wins\033[0m.')
        else:
            print("Utility is equal. \033[1mIt's a tie\033[0m.")
        
    
    #Reacting in case the user's input is not according to the asked input.
    #Proceed accordingly after receiving the correct input from the user.
    elif str(fin_choice_pl.lower()) != 'fight' or str(fin_choice_pl.lower()) != 'no':
         while str(fin_choice_pl.lower()) != 'fight' or str(fin_choice_pl.lower()) != 'no':
            print(Fore.RED + "Sorry, I don't understand. Please answer 'Fight' or 'No'")
            print(Style.RESET_ALL)
            fin_choice_pl = str(input('What is your decision?' + Fore.GREEN + ' Fight or no? '))
            if fin_choice_pl.lower() == 'fight' and comp_choice == 'enter':
                print('Final result: ' + Fore.RED + f"""\033[1mEnter the market. Fighting.\033[0m 
                        Utility:\t{results_dict['Enter market'][0]}
                        This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                if rand_res_1 < rand_res_2:
                    print('You have higher utility. \033[1mYou win\033[0m.')
                elif rand_res_1 > rand_res_2:
                    print('BD has higher utility. \033[1mBD wins\033[0m.')
                else:
                    print("Utility is equal. \033[1mIt's a tie\033[0m.")
                break

            elif fin_choice_pl.lower() == 'no' and comp_choice == 'enter':
                print('Final result: ' + Fore.RED + f"""\033[1mEnter the market. No fighting.\033[0m 
                        Utility:\t{results_dict['Enter market'][1]}
                        This result is \033[1mNash Equilibrium.\033[0m""")
                if rand_res_3 < rand_res_4:
                    print('You have higher utility. \033[1mYou win\033[0m.')
                elif rand_res_3 > rand_res_4:
                    print('BD has higher utility. \033[1mBD wins\033[0m.')
                else:
                    print("Utility is equal. \033[1mIt's a tie\033[0m.")
                break

            elif fin_choice_pl.lower() == 'fight' and comp_choice == 'out':
                print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. Fighting.\033[0m 
                        Utility:\t{results_dict['Out'][0]}
                        This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                if rand_res_5 < rand_res_6:
                    print('You have higher utility. \033[1mYou win\033[0m.')
                elif rand_res_5 > rand_res_6:
                    print('BD has higher utility. \033[1mBD wins\033[0m.')
                else:
                    print("Utility is equal. \033[1mIt's a tie\033[0m.")
                break

            elif fin_choice_pl.lower() == 'no' and comp_choice == 'out':
                print('Final result: ' + Fore.RED + f"""\033[1mStay out of the market. No fighting.\033[0m 
                        Utility:\t{results_dict['Out'][1]}
                        This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                print(Fore.GREEN +'But you have the highest utility. You should be very happy! Congratulations! :) ')
                print(Style.RESET_ALL)
                if rand_res_7 < rand_res_8:
                    print('You have higher utility. \033[1mYou win\033[0m.')
                elif rand_res_7 > rand_res_8:
                    print('BD has higher utility. \033[1mBD wins\033[0m.')
                else:
                    print("Utility is equal. \033[1mIt's a tie\033[0m.")
                break
                
                
#If user decided not to play. Repeat the game between Python 5 times.
#First player's choice is random. Second player reacts based on the higher utility.
if play_yn_1 == 0:
    pl_1 = 0
    pl_2 = 0
    
    #Asking user how many rounds he/she want computer to play
    num_of_rounds = input("How many rounds do you want me to play? (no more than 25, because I'm lazy) ")
    #Asking until the user put proper numeric answer for this question
    while str(num_of_rounds).isnumeric() == False:
        if str(num_of_rounds).isnumeric() == False:
                print('You are playing with me... Try again')
                num_of_rounds = input('How many rounds you want to play? ')
    #Killing the process if person put number bigger than 25
    if int(num_of_rounds) > 25:
        print("Oh no! More than 25 is too much for my computer brain. I'm dying... I'll explode in...")
        for n in range (10,-1,-1):
            print(n)
            time.sleep(0.9)
        print("Goodbye, evil world!!!😭 ")
        print("""Good will: I'm sorry. I'm dead. Please, try to revive me.
        Read my instructions more carefully next time. Don't kill me. Please.""")
        
    #If the person put proper number, continue the process    
    else:
            for i in range(0,int(num_of_rounds)):
                rand_choice_4 = np.random.choice(['Enter','Out'])
                if rand_choice_4 == 'Enter':
                    if rand_res_2 > rand_res_4:
                        print('Final result: ' + Fore.RED + f"""Player 1 decided to \033[1mEnter the market\033[0m. 
                        Player 2 decided to \033[1mFight\033[0m.
                            Utility:\t{results_dict['Enter market'][0]}
                            This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                        print(Style.RESET_ALL)
                        if rand_res_1 < rand_res_2:
                            print('Player 2 have higher utility. \033[1mPlayer 2 wins\033[0m.\n')
                            pl_2 += 1
                        elif rand_res_1 > rand_res_2:
                            print('Player 1 has higher utility. \033[1mPlayer 1 wins\033[0m.\n')
                            pl_1 += 1
                        else:
                            print("Utility is equal. \033[1mIt's a tie\033[0m.\n")

                    elif rand_res_2 < rand_res_4:
                        print('Final result: ' + Fore.RED + f"""Player 1 decided to \033[1mEnter the market\033[0m. 
                        Player 2 decided to \033[1mNot to fight\033[0m.
                            Utility:\t{results_dict['Enter market'][1]}
                            This result is \033[1m Nash Equilibrium.\033[0m""")
                        print(Style.RESET_ALL)
                        if rand_res_3 < rand_res_4:
                            print('Player 2 have higher utility. \033[1mPlayer 2 wins\033[0m.\n')
                            pl_2 += 1
                        elif rand_res_3 > rand_res_4:
                            print('Player 1 has higher utility. \033[1mPlayer 1 wins\033[0m.\n')
                            pl_1 += 1
                        else:
                            print("Utility is equal. \033[1mIt's a tie\033[0m.\n")

                    #In case of equal utility for the strategies, second move is randomly chosen 
                    else:
                        print('Player 2 is indifferent between options. Choice will be done randomly')
                        rand_choice_5 = np.random.randint(0,2)
                        if rand_choice_5 == 0:
                            print('Final result: ' + Fore.RED + f"""Player 1 decided to \033[1mEnter the market\033[0m. 
                            Player 2 decided to \033[1mFight\033[0m.
                                Utility:\t{results_dict['Enter market'][0]}
                                This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                            print(Style.RESET_ALL)
                            if rand_res_1 < rand_res_2:
                                print('Player 2 have higher utility. \033[1mPlayer 2 wins\033[0m.\n')
                                pl_2 += 1
                            elif rand_res_1 > rand_res_2:
                                print('Player 1 has higher utility. \033[1mPlayer 1 wins\033[0m.\n')
                                pl_1 += 1
                            else:
                                print("Utility is equal. \033[1mIt's a tie\033[0m.\n")

                        else:
                            print('Final result: ' + Fore.RED + f"""Player 1 decided to \033[1mEnter the market. 
                            Player 2 decided to \033[1mNot to fight\033[0m.
                                Utility:\t{results_dict['Enter market'][1]}
                                This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                            print(Style.RESET_ALL)
                            if rand_res_3 < rand_res_4:
                                print('Player 2 have higher utility. \033[1mPlayer 2 wins\033[0m.\n')
                                pl_2 += 1
                            elif rand_res_3 > rand_res_4:
                                print('Player 1 has higher utility. \033[1mPlayer 1 wins\033[0m.\n')
                                pl_1 += 1
                            else:
                                print("Utility is equal. \033[1mIt's a tie\033[0m.\n")

                else:
                    if rand_res_6 > rand_res_8:
                        print('Final result: ' + Fore.RED + f"""Player 1 decided to \033[1mStay out of the market\033[0m. 
                        Player 2 decided to \033[1mFight\033[0m.
                            Utility:\t{results_dict['Out'][0]}
                            This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                        print(Style.RESET_ALL)
                        if rand_res_5 < rand_res_6:
                            print('Player 2 have higher utility. \033[1mPlayer 2 wins\033[0m.\n')
                            pl_2 += 1
                        elif rand_res_5 > rand_res_6:
                            print('Player 1 has higher utility. \033[1mPlayer 1 wins\033[0m.\n')
                            pl_1 += 1
                        else:
                            print("Utility is equal. \033[1mIt's a tie\033[0m.\n")

                    elif rand_res_6 < rand_res_8: 
                        print('Final result: ' + Fore.RED + f"""Player 1 decided to \033[1mStay out of the market\033[0m. 
                        Player 2 decided to \033[1mNot to fight\033[0m.
                            Utility:\t{results_dict['Out'][1]}
                            This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                        print(Style.RESET_ALL)
                        if rand_res_7 < rand_res_8:
                            print('Player 2 have higher utility. \033[1mPlayer 2 wins\033[0m.\n')
                            pl_2 += 1
                        elif rand_res_7 > rand_res_8:
                            print('Player 1 has higher utility. \033[1mPlayer 1 wins\033[0m.\n')
                            pl_1 += 1
                        else:
                            print("Utility is equal. \033[1mIt's a tie\033[0m.\n")

                    #In case of equal utility for the strategies, second move is randomly chosen 
                    else:
                        print('Player 2 is indifferent between options. Choice will be done randomly')
                        rand_choice_6 = np.random.randint(0,2)
                        if rand_choice_6 == 0:
                            print('Final result: ' + Fore.RED + f"""Player 1 decided to \033[1mStay out of the market\033[0m. 
                            Player 2 decided to \033[1mFight\033[0m.
                                Utility:\t{results_dict['Out'][0]}
                                This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                            print(Style.RESET_ALL)
                            if rand_res_5 < rand_res_6:
                                print('Player 2 have higher utility. \033[1mPlayer 2 wins\033[0m.\n')
                                pl_2 += 1
                            elif rand_res_5 > rand_res_6:
                                print('Player 1 has higher utility. \033[1mPlayer 1 wins\033[0m.\n')
                                pl_1 += 1
                            else:
                                print("Utility is equal. \033[1mIt's a tie\033[0m.\n")

                        else:
                            print('Final result: ' + Fore.RED + f"""Player 1 decided to \033[1mStay out of the market\033[0m. 
                            Player 2 decided to \033[1mNot to fight\033[0m.
                                Utility:\t{results_dict['Out'][1]}
                                This result is \033[1mnot a Nash Equilibrium.\033[0m""")
                            print(Style.RESET_ALL)
                            if rand_res_7 < rand_res_8:
                                print('Player 2 have higher utility. \033[1mPlayer 2 wins\033[0m.\n')
                                pl_2 += 1
                            elif rand_res_7 > rand_res_8:
                                print('Player 1 has higher utility. \033[1mPlayer 1 wins\033[0m.\n')
                                pl_1 += 1
                            else:
                                print("Utility is equal. \033[1mIt's a tie\033[0m.\n")

            print(Back.BLUE + '\033[1mFinal results:\033[0m' + Style.RESET_ALL + f'\nPlayer 1 won: \033[1m{pl_1}\033[0m times. Player 2 won \033[1m{pl_2}\033[0m times.')
