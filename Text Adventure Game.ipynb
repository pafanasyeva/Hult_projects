# %% [markdown]
# # Horror Text Adventure Game
#
# This game is created by **Polina Afanasyeva**.
#
# This is a game in the genre **Horror story and subgenre Home Invasion**.
#
# It is inspired by such games as *Fears to Fathom: Home Alone, Fears to Fathom:Carson House, Suffer the Night, Stories Untold (The House Abandon), Behind you*.
#
# **Description:** \
# This game is a classic text adventure game, where you have a description of the situation and you are asked to make a move or action you think appropriate or more logical in this situation. The game react accordingly. If your move/action is not included in the possible list of actions allowed to the player, the program will ask to make a move again, until the proper answer will be typed. There are 4 endings for this game.
#
#  ***!!! This game has a background music. For the full experience, please, turn your sound on. !!!***
#
# If you are sensitive and easily impressionable, please, don't play this game in the dark room and alone.
#
# | **Thank you! Good luck and have fun!** |
#
# Sources used: \
#     1. Image:https://mykaleidoscope.ru/interer/98654-krovat-v-temnote-70-foto.html \
#     2. Image: https://pixabay.com/vectors/doorway-spooky-dark-closet-light-4114564/ \
#     3. Image: DALLE \
#     5. Image: https://almode.ru/interer/35148-osveschenie-na-kuhne-v-kvartire-60-foto.html \
#     6. Music: https://www.youtube.com/watch?v=svAspF0nxC0\

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import image as mpimg
from IPython.display import Audio 
from IPython.display import display
from colorama import Fore, Back, Style
import time

#Beggining the game with the start function, which includes discription, picture and lead further.
def start():
    print(Fore.BLUE + """
    You open your eyes and see only darkness around you... Where are you? What year is it?..
You blink a few times and start to see a weak light from the window. You see how dark starts 
to recede and takes shapes similar to furniture. You are lying down in your bed. You remembered
that it was a really harsh week at work and you decided to take a small nap during the day on Saturday.
You stretch a little to throw final sleepiness from you and get off your bed. You feel a little bit
anxious because of your dream. You can't remember what was in your dream. Only unsettling feeling is left.
    """)
    #Reset all of the colors to default.
    print(Style.RESET_ALL)
    
    #Show picture
    image = mpimg.imread("./_images/bedroom_night.jpg")
    plt.figure(figsize=(80,60))
    plt.axis('off')
    plt.imshow(image)
    plt.show()
    
    #Put to sleep giving computer time to proceed so that the input didn't get before picture or text.
    #Will be used further after pictures/big inputs.
    time.sleep(0.5)
    
    #In case you want to see the map of all of the possible actions in the game before playing:
    #type 'map' in the first input.
    map_ = input("<Press 'enter' to continue> ")
    if map_ == 'map':
        image5 = mpimg.imread("./_images/game_map.png")
        plt.figure(figsize=(100,80))
        plt.axis('off')
        plt.imshow(image5)
        plt.show()
        
        time.sleep(0.8)
    
    stage_1()
    
#Defining the function for the first stage of the game, asking player to move and react based on possible answers.
def stage_1():
    print(Fore.BLUE + """You are unsure what you should do first... 
    Look around? Or maybe check the window? Turn on the light? Or check new messages?""")
    print(Style.RESET_ALL)
    
    time.sleep(0.5)
    move_1 = input('What do want to do now? ')
    
    #list of possible inputs from the player
    list_actions_1 = [['look around', 'look'], 
                      ['go to the window', 'window','check window', 'check', 'look outside', 'outside'], 
                      ['turn on the light', 'light', 'stand up', 'turn on', 'turn on light','the light'], 
                      ['take the phone', 'take phone', 'phone', 'take my phone','check the phone', 
                       'check phone', 'check messages', 'messages', 'turn on flashlight', 'flashlight', 'check new messages']]
    
    #React based on the action the player took. Proceed to the next function.
    if move_1.lower() in list_actions_1[0]:
        look_around()
    
    elif move_1.lower() in list_actions_1[1]:
        window()
        
    elif move_1.lower() in list_actions_1[2]:
        light()
    
    elif move_1.lower() in list_actions_1[3]:
        phone()
    
    #If input of the player is unknown, ask again until getting understandable answer.
    else:
        while move_1.lower() not in list_actions_1[0] or move_1.lower() not in list_actions_1[1] or move_1.lower() not in list_actions_1[2] or move_1.lower() not in list_actions_1[3]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_1 = input('What do want to do now? ')
            
            if move_1.lower() in list_actions_1[0]:
                look_around()
                break

            elif move_1.lower() in list_actions_1[1]:
                window()
                break

            elif move_1.lower() in list_actions_1[2]:
                light()
                break

            elif move_1.lower() in list_actions_1[3]:
                phone()
                break

#Define the function if person decided to look around. Ask him again for the next action. React accordingly with different actions.                
def look_around():
    print(Fore.BLUE + """\nYou are looking around you, but you can see only dark unstructured 
shapes. Without seeing anything you can hardly do or find anything.""")
    print(Style.RESET_ALL)
    time.sleep(0.3)
    move_2 = input('What do you want to do next? ')
    list_actions_2 = [['go to the window', 'window','check window', 'check', 'look outside', 'outside'], 
                      ['turn on the light', 'light', 'stand up', 'turn on', 'turn on light','the light'], 
                      ['take the phone', 'take phone', 'phone', 'take my phone','check the phone', 
                       'check phone', 'check messages', 'messages', 'turn on flashlight', 'flashlight','check new messages']]
    if move_2.lower() in list_actions_2[0]:
        window()
        
    elif move_2.lower() in list_actions_2[1]:
        light()
        
    elif move_2.lower() in list_actions_2[2]:
        phone()
    
    #If answer of the user is not in the list of possible actions, keep asking until getting an understandable answer
    else:
        while move_2.lower() not in list_actions_2[0] or move_2.lower() not in list_actions_2[1] or move_2.lower() not in list_actions_2[2]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_2 = input('What do you want to do next? ')
            
            if move_2.lower() in list_actions_2[0]:
                window()
                break

            elif move_2.lower() in list_actions_2[1]:
                light()
                break

            elif move_2.lower() in list_actions_2[2]:
                phone()
                break
    
#Define the function for action of the user connected with the window. Ask user for further action and react accordingly,
#using functions for each decision.
def window():
    print(Fore.BLUE + """\nYou are coming closer to the window and see how snow is lazily falling
down, without being disturbed or fastened by the wind. The warm street lights 
illuminate the ground and some areas around them. You can see how beautifully 
snow sparkles under the light. The falling snow also adds magic to the scene, 
making you feel like its small sparkling fairies dancing under the light.
Everything else was peaceful. As usual, there are some rare lights inside your 
neighbors’ houses. Probably, everyone is also relaxing after the hard-working week 
and takes their time to spend these couple of evenings with their loved ones. 
You slightly smile at your thoughts and nearly move away from the window, 
when the parked car near your neighbor’s house caught your eye. You find it 
a little bit strange because from what you heard they went on a vacation and should 
come back tomorrow. But maybe you just understood something wrong... You mentally 
shrug to your own thoughts and move away from the window. """)
    print(Style.RESET_ALL)
    time.sleep(0.5)
    move_3 = input('What do you want to do next? ')
    list_actions_3 = [['turn on the light', 'light', 'stand up', 'turn on', 'turn on light','the light'], 
                      ['take the phone', 'take phone', 'phone', 'take my phone','check the phone', 
                       'check phone', 'check messages', 'messages', 'turn on flashlight', 'flashlight','check new messages']]
    if move_3.lower() in list_actions_3[0]:
        light()
        
    elif move_3.lower() in list_actions_3[1]:
        phone()
     
    #Continue to ask user if the initial answer is not in the list of possible actions. Proceed after receive correct input.
    else:
        while move_3.lower() not in list_actions_3[0] or move_3.lower() not in list_actions_3[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_3 = input('What do you want to do next? ')
            
            if move_3.lower() in list_actions_3[0]:
                light()
                break

            elif move_3.lower() in list_actions_3[1]:
                phone()
                break
        

#Define the function for the action "turn on light". Ask for further action, react accordingly.
def light():
    print(Fore.BLUE + """\nYou are slowly moving towards the light switch when you accidentally
tripped over something on the floor. You nearly fell but were able to keep 
your balance. Swearing mentally on your unluckiness and feeling a slight pain 
in the ankle, you move further and finally turn on the light. The warm light 
breaks through the darkness of the room, finally showing the true form of all 
of the shapes. You turn around, taking a quick look around. Nothing special 
can be seen, everything looks the same as you left it before going to sleep. 
The object that made you stumbled appeared to be just a pair of shoes
on the floor. You sigh and suddenly hear the sound from your stomach. You definitely
need to eat.""")
    print(Style.RESET_ALL)
    time.sleep(0.5)
    move_4 = input('Do you want to order pizza or cook for yourself? ')
    list_actions_4 = [['order', 'order pizza', 'pizza', 'order some pizza', 'the pizza', 'order a pizza', 'order the pizza'],
                     ['cook', 'kitchen', 'cook for yourself']]
    
    if move_4.lower() in list_actions_4[0]:
        pizza()
    
    elif move_4.lower() in list_actions_4[1]:
        cook()
    
    #Continue asking until receive the input in list of actions.
    else:
        while move_4.lower() not in list_actions_4[0] or move_4.lower() not in list_actions_4[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_4 = input('Do you want to \033[1morder pizza\033[0m or \033[1mcook for yourself\033[0m? ')
            
            if move_4.lower() in list_actions_4[0]:
                pizza()
                break

            elif move_4.lower() in list_actions_4[1]:
                cook()
                break
        
        

#Define the function for the action "take phone". React accordingly with the action of the player and ask for the next move.
def phone():
    print(Fore.BLUE + """\nYou are taking the phone and looking at the time. It's already 8pm. 
8 pm in the winter can be super dark, you are feeling it now. You quickly 
check the messages you got while sleeping, turn on the flashlight, and go 
to the light switch. You nearly stumbled due to the shoes lying right 
in your path, but the flashlight on your phone helped you to notice them 
in time. After turning on the light, you return to your desk and turn on 
your computer. You are waiting patiently for your computer to turn on and 
drinking a glass of water, which was left on your desk before sleeping.""")
    print(Style.RESET_ALL)
    time.sleep(0.5)
    move_5 = input("""You have a sudden thought that you want to eat something. 
You are indecisive what you should do: order some pizza or cook for yourself? """)
    list_actions_5 = [['order', 'order pizza', 'pizza', 'order some pizza', 'the pizza', 'order a pizza', 'order the pizza'],
                     ['cook', 'kitchen', 'cook for yourself']]
    if move_5.lower() in list_actions_5[0]:
        pizza()
        
    elif move_5.lower() in list_actions_5[1]:
        cook()
    
    #In case of receive incorrect input, ask until receive input which was included in the list of actions. Proceed accrodingly.
    else:
        while move_5.lower() not in list_actions_5[0] or move_5.lower() not in list_actions_5[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_5 = input("Do you want to \033[1morder pizza\033[0m or \033[1mcook\033[0m? ")
            
            if move_5.lower() in list_actions_5[0]:
                pizza()
                break

            elif move_5.lower() in list_actions_5[1]:
                cook()
                break
        

#Define the function for the decision "cook". Print the description, ask for the next action and procced accrodingly. 
def cook():
    print(Fore.BLUE + """\nYou are lazily going downstairs to the kitchen and start cooking 
your favorite dish. After some time, when the meal is finally done, you take 
your plate and go upstairs again. You are too lazy to think about anything else.
You just want to rest. You come back to your room, turn off lights on 
your way up, and sit at the computer desk, putting your plate down. You are 
turning on some videos in the background for making yourself more entertained.


When you are almost done eating, suddenly you hear the crash of a plate and 
turn your head to the open door, leading to the seemingly quiet corridor. 
The sudden sound caught you off guard. You are feeling how adrenalin goes up. 
Is someone there or is it just you accidentally didn't put the plate in the 
sink properly?""")
    print(Style.RESET_ALL)
    time.sleep(0.5)
    move_6 = input('What do you want to do next? ')
    list_actions_6 = [['ignore', 'ignore the sound', 'stay'],
                     ['check', 'go check', 'go downstairs', 'downstairs', 'go down', 'go to kitchen', 'go to the kitchen',
                     'return', 'return to the kitchen', ' return to kitchen', 'kitchen', 'go to check']]
    
    if move_6.lower() in list_actions_6[0]:
        print(Fore.BLUE + """\nYou decided that it's just your imagination and stays in your
place. 10 minutes after, you were almost done eating and were ready to get up,
when you feel some strange movement behind your back and see the dark 
figure mirrored on your screen. You quickly turn your head back and at 
the same time, you feel the awful pain in your head. Your last memory 
falling from your chair and seeing black shoes near your eyes.""")
        fail()
        
    elif move_6.lower() in list_actions_6[1]:
        move_ = 'cook'
        move0 = 'check'
        stage_2(move_, move0)

    #Continue asking the user about the move, if unput is not in the list of actions.
    #Proceed accordingly after receiving correct input.
    else:
        while move_6.lower() not in list_actions_6[0] or move_6.lower() not in list_actions_6[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_6 = input("Will you \033[1mignore\033[0m or \033[1mgo check\033[0m? ")
            if move_6.lower() in list_actions_6[0]:
                print(Fore.BLUE + """\nYou decided that it's just your imagination and stays in your
place. 10 minutes after, you were almost done eating and were ready to get up,
when you feel some strange movement behind your back and see the dark 
figure mirrored on your screen. You quickly turn your head back and at 
the same time, you feel the awful pain in your head. Your last memory 
falling from your chair and seeing black shoes near your eyes.""")
                fail()
                break
                
            #Define the variables, which will be used in the stage_2 function in order to react for the user's choices.
            elif move_6.lower() in list_actions_6[1]:
                move_ = 'cook'
                move0 = 'check'
                stage_2(move_, move0)
                break
            
            
#Define the function for the choice to order pizza. Ask for the next move. Save results and proceed.     
def pizza():
    print(Fore.BLUE + """\nYou are taking your phone and opening an app to order pizza. You 
scroll down all of the variants you have at this late hour and finally find
a place where you can order tasty and not-so-expensive pizza. The restaurant
is unknown to you, but you see lots of good reviews. You click the button 
and wait for the app to proceed. It says that it will take around 40 minutes 
to deliver your pizza. You sigh sadly feeling how your stomach is not happy
about it, but you can do nothing about it.
You start scrolling your Insta and put video with a calming sound on the 
background on your computer.
After 40 minutes you hear the doorbell. You take your phone and go downstairs.
You come to the door. You can't decide... Should you check peephole first or just open the door?""")
    print(Style.RESET_ALL)
    time.sleep(0.5)
    move_7 = input('What do you want to do next? ')
    list_actions_7 = [['look at the peephole','look', 'look at peephole', 
                       'peephole', 'check', 'check the peephole',
                      'check peephole', 'look through peephole', 'look peephole'],
                     ['open the door', 'open', 'open door', 'door']]
    
    #Define the variables, which will be used in the stage_2 function in order to react for the user's choices.
    if move_7.lower() in list_actions_7[0]:
        move_ = 'pizza'
        move0 = 'peephole'
        stage_2(move_, move0)
        
    #Define the variables, which will be used in the stage_2 function in order to react for the user's choices.
    elif move_7.lower() in list_actions_7[1]:
        move_ = 'pizza'
        move0 = 'door'
        stage_2(move_, move0)
        
    #Conrinue asking until get the understandable input. Proceed accordingly.
    else:
        while move_7 not in list_actions_7[0] or move_7 not in list_actions_7[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_7 = input("Will you \033[1mcheck the peephole\033[0m or \033[1mopen the door\033[0m? ")
            if move_7.lower() in list_actions_7[0]:
                move_ = 'pizza'
                move0 = 'peephole'
                stage_2(move_, move0)
                break

            elif move_7.lower() in list_actions_7[1]:
                move_ = 'pizza'
                move0 = 'door'
                stage_2(move_, move0)
                break

                
#-----------------------------------------------------------------------------
#STAGE 2

#Define the stage 2 with 2 variables in order to react accordingly to the previous choices of the player.
def stage_2(a,b):
    print(Fore.CYAN + "You're thinking about your next actions while going downstairs. It takes some time.")
    print(Style.RESET_ALL)
    music()
    
    #Give time for program to proceed
    time.sleep(0.8)
    
    #Decide further actions based on the previous choice of the player from the stage 1.
    #If there is a mistake, print warning.
    try:
        if a == 'cook' and b == 'check':
            cook_check()

        elif a == 'pizza' and b == 'peephole':
            pizza_peephole()

        elif a == 'pizza' and b == 'door':
            open_door()

    except:
        print(Fore.RED + """\033[1m Something went wrong. Contact the developer to fix bugs in the game. Thank you.\033[0m
Meanwhile, restart the game and try another path.""")
        #stage_1()
        

#Define the function for the player deciding to go cooking and further situation. 
#Showing picture of the kitchen. Ask player for further actions and react accordingly.
def cook_check():   
    image4 = mpimg.imread("./_images/kitchen.jpg")
    plt.figure(figsize=(80,60))
    plt.axis('off')
    plt.imshow(image4)
    plt.show()
    
    print(Fore.BLUE + """\nYou slowly go downstairs and turn on the light in the kitchen. 
You see the plate on the broken plate on the floor near the sink. Was it 
really just your imagination and you just wasn't accurate enough with your
dishes? Or is it not just that and there is someone in the house?""")
    print(Style.RESET_ALL)
    
    time.sleep(0.7)
    
    move_8 = input('What will you do? ')
    list_actions_8 = [['look','look around','look around the room','look around room', 
                       'check', 'check the room', 'check room'],
                     ['ignore','don\'t pay attention', 'keep cleaning', 'clean the shards',
                      'clean', 'come closer', 'closer', 'go to the sink', 'go to sink']]
    if move_8.lower() in list_actions_8[0]:
        check_look()
        
    elif move_8.lower() in list_actions_8[1]:
        print(Fore.BLUE + """\nYou decided that it was just your clumsiness again. You sigh 
and start to clean the shards. Suddenly you feel the presence behind you.
Unfortunately, you don't have enough time to turn. You feel pain in the back
of your head and the coldness of the floor in your kitchen.""")
        fail()
    
    #Continue asking for correct input that was included in the list of actions. Proceed accordingly.
    else:
        while move_8.lower() not in list_actions_8[0] or move_8.lower() not in list_actions_8[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_8 = input('What will you do? \033[1mLook around\033[0m or \033[1mignore\033[0m? ')
            if move_8.lower() in list_actions_8[0]:
                check_look()
                break
                
            elif move_8.lower() in list_actions_8[1]:
                print(Fore.BLUE + """\nYou decided that it was just your clumsiness again. You sigh 
and start to clean the shards. Suddenly you feel the presence behind you.
Unfortunately, you don't have enough time to turn. You feel pain in the back
of your head and the coldness of the floor in your kitchen.""")
                fail()
                break
                
                
#Define the function for the next actions when the person went to check and looked around the kitchen.
#Ask the player for further move and proceed to the next function according to the decision.
def check_look():
    print(Fore.BLUE + """\nYou are sure that it is not just your imagination. You start to 
look around the kitchen and see a little bit of dirt on the floor near the
sink. You are sure that there is definitely someone else in your house.""")
    print(Style.RESET_ALL)
    time.sleep(0.3)
    move_9 = input('What will you do? ')
    list_actions_9 = [['shout', 'call', 'scream', 'shout to check', 'shout who\'there?', 
                       'shout who\'there', 'go check', 'look closer', 'shout: who\'there?'],
                     ['return', 'go upstairs', 'run to the room', 'run to my room', 'run to room',
                      'return to my room', 'go to my room', 'return upstairs', 'return to the room']]
    
    if move_9.lower() in list_actions_9[0]:
        print(Fore.BLUE + """\nYou shout and wait for a second. It's quiet. Was everything just your imagination?
You hear the voice behind you:""")

        print(Fore.RED + """
-\033[1m Well, that's some sad news for me. But I also have a weapon\033[0m.""")

        print(Fore.BLUE + """
You turn around and see the huge man in the black mask. Almost immediately you
feel pain in your stomach. You take a few steps back and look down. There is a
knife in your stomach and your clothes start to turn red. With shaking hands, you
try to feel your stomach, but your vision becomes blurry, and you fall onto the cold kitchen
floor. The last thing you feel is the coldness of the floor.""")
        fail()
        
    elif move_9.lower() in list_actions_9[1]:
        return_room()
               
    #Continue asking the player in case of the wrong input. Proceed accordingly.       
    else:
        while move_9 not in list_actions_9[0] or move_9 not in list_actions_9[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_9 = input('What do you want to do? \033[1mShout to check\033[0m or \033[1mreturn to the room\033[0m? ')
            if move_9.lower() in list_actions_9[0]:
                print(Fore.BLUE + """\nYou shout and wait for a second. It's quiet. Was everything just your imagination?
You hear the voice behind you:""")

                print(Fore.RED + """
-\033[1m Well, that's some sad news for me. But I also have a weapon\033[0m.""")

                print(Fore.BLUE + """
You turn around and see the huge man in the black mask. Almost immediately you
feel pain in your stomach. You take a few steps back and look down. There is a
knife in your stomach and your clothes start to turn red. With shaking hands, you
try to feel your stomach, but your vision becomes blurry, and you fall onto the cold kitchen
floor. The last thing you feel is the coldness of the floor.""")
                fail()
                break
        
            elif move_9.lower() in list_actions_9[1]:
                return_room()
                break
                
#Define this function, so it will be easier to connect 2 different path in one for the final stage 3.            
def return_room():
    print(Fore.BLUE + """\nYou queitly and as fast as possible go upstairs to your room.""")
    print(Style.RESET_ALL)
    move_10 = input("<Press 'enter' to continue> \n")
    stage_3()
        

#Define the function for the action of person in case of ordering pizza and checking peephole. Ask user for the next move
#and react accordingly. Proceed for the next functions based on the response from the user.
def pizza_peephole():
    print(Fore.BLUE + """\nYou look at the peephole but can't see anyone. For a second you
see the dark figure disappear around the corner toward the backyard. 
Imagination? You are a little bit confused and nervous. Maybe you get it wrong
and no one actually rings the bell? You check your phone but it shows that your
order is delivered.""")
    time.sleep(0.5)
    print(Style.RESET_ALL)
    move_11 = input("What do you want to do? ")
    list_actions_11 = [['open the door', 'open door', 'open', 'door'],
                      ['don\'t open the door', 'ignore', 'ignore and return', 'dont open the door',
                       'dont open door', 'don\'t open door', 'don\'t open',
                       'ignore and return to the room', 'return to the room', 'go upstairs',
                       'return', 'go to the room', 'go to room', 'dont open', 'not open']]
    
    if move_11.lower() in list_actions_11[0]:
        open_door()
        
    elif move_11.lower() in list_actions_11[1]:
        peephole_ignore()
               
    #Continue to ask the user if the input is not in the list of actions. Proceed after receiving the answer.
    else:
        while move_11.lower() not in list_actions_11[0] or move_11.lower() not in list_actions_11[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_11 = input('What do you want to do? \033[1mOpen the door\033[0m or \033[1mignore and return\033[0m? ')
            if move_11.lower() in list_actions_11[0]:
                open_door()
                break
                
            elif move_11.lower() in list_actions_11[1]:
                peephole_ignore()
                break
                
#Define the function for the move of opening the door with further asking of the next move from the player and 
#further reaction by moving to the next functions, based on the move.
def open_door():
    print(Fore.BLUE + """\nYou are opening the door and see the pizza box lying on the doorstep.
No one around, no car in front of your house. The street seems peaceful. You are 
confused but decide to take the pizza with you (moreover the app shows that 
the order was delivered). Still, you close the door and go upstairs to eat.
You place pizza on the table near your computer and sit. Still feeling anxious,
you start eating but the food doesn't feel so tasteful anymore. You put another slice
of pizza in the box and turn your head toward the corridor. It looks dark and quiet.
Maybe you shouldn't have left the door open?.. You are trying to get rid of the awful,
unsettling thoughts and turn to the computer to turn on some music to put yourself 
at ease. Suddenly you hear the floorboard creak downstairs. Is it your imagination again?..
Or not?""")
    print(Style.RESET_ALL)
    time.sleep(0.7)
    move_12 = input('What will you do next? ')
    list_actions_12 = [['close the door', 'close', 'call 911', '911', 'close door',
                        'close the door and call 911', 'close door and call 911'],
                      ['ignore', 'do nothing', 'ignore the sound', 'ignore sound']]
    
    if move_12.lower() in list_actions_12[0]:
        stage_3()
        
    elif move_12.lower() in list_actions_12[1]:
        print(Fore.BLUE + """\nYou decided that it is just a wild imagination due to the things
that happened earlier, so you decided to ignore the sounds. You put on your headphones
just to hear the calming music and don't think about that too much. The last
thing you felt was an awful pain in the back of the head.""")
        fail()
     
    #Continue asking until receiving the input in the list of possible actions.
    else:
        while move_12.lower() not in list_actions_12[0] or move_12.lower() not in list_actions_12[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_12 = input('What will you do next? \033[1mClose the door and call 911\033[0m or \033[1mignore\033[0m ')
            if move_12.lower() in list_actions_12[0]:
                stage_3()
                break
        
            elif move_12.lower() in list_actions_12[1]:
                print(Fore.BLUE + """\nYou decided that it is just a wild imagination due to the things
that happened earlier, so you decided to ignore the sounds. You put on your headphones
just to hear the calming music and don't think about that too much. The last
thing you felt was an awful pain in the back of the head.""")
                fail()
                break

#Define the function when the person decides not to open the door. Ask for further move.
#React accordingly.
def peephole_ignore():
    print(Fore.BLUE + """\nYou are feeling super anxious and decide not to open the door. 
Everything feels suspicious to you. You decide to go upstairs and stay there.
You go to your room, leaving the light in the corridor on and the door open just 
to see if everything is fine. You sit at your desk and look at the door for 15
seconds. Nothing happens. Was it your imagination and you should have opened 
the door and maybe find your pizza laying there? Your stomach doesn't 
like your decision and makes a loud sound showing dissatisfaction.""")
    print(Style.RESET_ALL)
    time.sleep(0.6)
    move_13 = input('What do you want to do? ')
    print(Style.RESET_ALL)
    list_actions_13 = [['stay in the room', 'stay', 'wait', 'stay in room', 'observe',
                        'stay and observe', 'stay and wait'],
                      ['go back', 'take pizza', 'go grab pizza', 'go downstairs', 'return',
                       'go for pizza', 'downstairs', 'pizza']]
    
    if move_13.lower() in list_actions_13[0]:
        stay_in_room()
        
    elif move_13.lower() in list_actions_13[1]:
        print(Fore.BLUE + """\nYou decided that you are over-exaggerating here, so you decide
to go downstairs and take this pizza. You go out of the room and go downstairs.
You are already near the door when you see out of the corner of your eye a dark figure
emerges from the darkness.""")
        
        print(Fore.RED + """
-\033[1m You forgot your pizza\033[0m.""")

        print(Fore.BLUE + """
That's the last you hear before feeling the pain at the back of your head and 
then the pain from falling to the floor. You see how black shoes come closer
to your face but can't keep your consciousness. Everything goes black.""")
        fail()
     
    #React in case of the wrong input of the player. Ask until receiving proper answer and proceed.
    else:
        while move_13.lower() not in list_actions_13[0] or move_13.lower() not in list_actions_13[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_13 = input('What will you do? \033[1mStay in the room\033[0m or \033[1mgo back\033[0m?')
            if move_13.lower() in list_actions_13[0]:
                stay_in_room()
                break
        
            elif move_13.lower() in list_actions_13[1]:
                print(Fore.BLUE + """\nYou decided that you are over-exaggerating here, so you decide
to go downstairs and take this pizza. You go out of the room and go downstairs.
You are already near the door when you see out of the corner of your eye a dark figure
emerges from the darkness.""")
        
                print(Fore.RED + """
-\033[1m You forgot your pizza\033[0m.""")

                print(Fore.BLUE + """
That's the last you hear before feeling the pain at the back of your head and 
then the pain from falling to the floor. You see how black shoes come closer
to your face but can't keep your consciousness. Everything goes black.""")
                fail()
                break

#Define the function for the users move of staying in the room. Ask for the further move.
#React accordingly to the decision.
def stay_in_room():
    print(Fore.BLUE + """\nYou decided to stay in your place for a little bit longer, just
to see how it will go. You mentally say sorry for your stomach, but decide
that your safety is more important.
Suddenly you hear the floorboard creak downstairs. Is it your imagination again?..
Or not?""")
    print(Style.RESET_ALL)
    move_14 = input('What will you do? ')
    list_actions_14 = [['close the door', 'close', 'call 911', '911', 'close door',
                        'close the door and call 911', 'close door and call 911'],
                      ['ignore', 'do nothing', 'ignore the sound', 'ignore sound']]
    
    if move_14.lower() in list_actions_14[0]:
        stage_3()
        
    elif move_14.lower() in list_actions_14[1]:
        print(Fore.BLUE + """\nYou decided that it is just a wild imagination due to the things
that happened earlier, so you decided to ignore the sounds. You put your headphones
just to hear the calming music and don't think about that too much. The last
thing you felt was an awful pain in the back of the head.""")
        fail()
        
    #Continue asking until receiving an understandable answer (move in the list of action). Proceed accordingly 
    #after getting an input that in in the list of possible answers.
    else:
        while move_14.lower() not in list_actions_14[0] or move_14.lower() not in list_actions_14[1]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_14 = input('What will you do? \033[1mClose the door and call 911\033[0m or \033[1mignore\033[0m?')
            if move_14.lower() in list_actions_14[0]:
                stage_3()
                break

            elif move_14.lower() in list_actions_14[1]:
                print(Fore.BLUE + """\nYou decided that it is just a wild imagination due to the things
that happened earlier, so you decided to ignore the sounds. You put your headphones
just to hear the calming music and don't think about that too much. The last
thing you felt was an awful pain in the back of the head.""")
                fail()
                break

                
#-----------------------------------------------------------------------------
#STAGE 3

#Defining the function for the stage 3. All of the previous decisions that did not end in fail lead to this
#scene and continue with further decisions of the player.
def stage_3():
    print(Fore.BLUE + """\nYou quickly and at the same time quietly close the door to the room.
There is definitely someone in your house. You take your phone and call 911.""")
    
    print(Fore.GREEN + """    
-\033[1m 911, what is your emergency?\033[0m

- There is someone in my house. I heard several noises downstairs. And I think
I saw the figure outside the house. Can you send the police, please?!""")
         
    #Asking user for his/her 'address' for better involvement in the game and atmosphere.
    input('\tMy address is...')
    
    #Make it looks like more natural response by postponing the immediate answer from the operator.
    time.sleep(1.1)
    print(Fore.GREEN + """\n-\033[1m Police is on their way. Please lock the door to your room and hide.
    They will be at your place in 10 minutes.\033[0m""")
    
    print(Fore.BLUE + """
You put down your phone and look at the closed door to your room. You are thinking
of your options. Of course, you can follow the advice, lock the room and hide. 
But then the intruder will definitely know that you are in the room. Are you sure
that the door will be enough to protect you until the police arrive? Or you can just hide?
Or you can take the baseball bat in your closet and fight for yourself... But you don't
know the goal of the intruder and what they have.""")
    
    print(Style.RESET_ALL)
    time.sleep(0.5)
    
    move_15 = input("There is a lot at stake. What will you do? ")
    list_actions_15 = [['hide', 'just hide', 'hide without closing the door',
                        'hide without closing door', 'leave door open'],
                      ['close the door and hide', 'close and hide', 'close door and hide',
                       'close', 'door', 'close the door', 'close door'],
                      ['fight', 'take the bat', 'take bat', 'bat', 'take the baseball bat',
                       'baseball bat', 'take baseball bat']]
    
    if move_15.lower() in list_actions_15[0]:
        hide()
        
    elif move_15.lower() in list_actions_15[1]:
        close_hide()
        
    elif move_15.lower() in list_actions_15[2]:
        fight()
    
    #Asking the user for the understandable input and proceed accordingly after the answer.
    else:
        while move_15.lower() not in list_actions_15[0] or move_15.lower() not in list_actions_15[1] or move_15.lower() not in list_actions_15[2]:
            print(Fore.RED + "Sorry, I don't understand. Try again.\n")
            print(Style.RESET_ALL)
            move_15 = input('What will you do?! \033[1mHide\033[0m, \033[1mclose the door and hide\033[0m or \033[1mfight\033[0m???')
            if move_15.lower() in list_actions_15[0]:
                hide()
                break

            elif move_15.lower() in list_actions_15[1]:
                close_hide()
                break

            elif move_15.lower() in list_actions_15[2]:
                fight()
                break
            
            
            
#Defining one of the ending functions with pictures and explanation of the situation.
#Randomize the result with some chance to get one of the endings.
#20% to get Ending 1. 80% to get Ending 2.
def hide():
    print(Fore.BLUE + """\nYou decide to hide without closing the door so that the intruder
thinks that you've left the house or somewhere in another place. You quickly turn
off the light and think about the place to hide. You think under the bed is
too obvious and open, so you decide to get inside the closet and cover yourself with
the clothes.

You hear quiet footsteps coming closer to the door. You hold your breath and
hear the door handle turn. Quiet footsteps getting closer. Through the bars in the closet
door, you see a figure walking past the closet and going further into the room. 
The figure in the black mask comes to your bed and looks under it. A few seconds
later it starts to look around the whole room. You try to breathe as quietly as 
possible, holding your breath at the time when the figure comes closer. You try not to
hold your breathing for too long so that later you won't make a loud sound trying 
to catch your breath. Maybe it was a better decision to fight? Or close the door?..""")
    
    image2 = mpimg.imread("./_images/figure.png")
    plt.figure(figsize=(80,60))
    plt.axis('off')
    plt.imshow(image2)
    plt.show()
    
    time.sleep(0.3)
    
    print(Fore.BLUE + """
You try not to think about this at such a moment and see how the figure comes 
to the final place it didn't look: the place you are hiding. You cover your mouth
and nose with one hand and lean harder against the wall.""")
    
    rand_choice_1 = np.random.randint(0,100)
    if rand_choice_1 > 20:
        print(Fore.BLUE + """\nThe sound of a police siren can be heard from afar. The figure turns
his head toward the window. Even from your place, you can feel his disappointment.
The intruder clicks his tongue and runs out of the room. You put your hand down and 
breathe in. You slowly get out of the room and move downstairs. You can see the
police cars in front of your house. You go to the door and open it right in time
for policemen to come. They started to ask questions, you try to explain to them and
say that the intruder just ran away, and they have a chance to catch him. Police
go to check your house. You sit on the stairs outside and cover your face with 
your hands. The only thought you have right now is a pray for them to catch the intruder
as fast as possible.

\033[1mENDING 2\033[0m""")
        
    else:
        print(Fore.BLUE + """\nSuddenly the door to the closet opens and the figure looks 
stright at you.\n""")
        
        #Make the intruder words scarier by timming them and making it say one word in 0.35 sec.
        text1 = """-\033[1m There you are... Hide and Seek is over\033[0m.""".split(' ')
        for p in text1:
            print(Fore.RED + p, end = ' ')
            time.sleep(0.35)

        print(Fore.BLUE + """
You can swear that you heard a quiet laugh from the intruder.
He takes your hand and easily through you out of the wardrobe. You fell on the
floor and couldn’t even move when you feel the pain at the back of your 
head and the world goes black.

You were found dead. Next time luck will be on your side.
Or maybe you should have done something else? 

\033[1mENDING 1\033[0m""")
    
    
#Defining the second possible option for the ending.
#Also randomizing the result.
#10% to get ending 1. 90% to get ending 2.
def close_hide():
    print(Fore.BLUE + """\nYou decided to follow the advice. You close the door, turn off 
the light and start to look around for a place to hide. A few seconds later you
decide to hide in the closet as it seems safer than hiding under the bed.
You hear quiet footsteps coming closer to the door. You hear a door handle turn.
But the door doesn't open.\n""")
    
    #Make the intruder words scarier by timming them and making it say one word in 0.35 sec.
    text1 = """-\033[1m There you are. Wanted to play hide and seek? No worries, I know you are there. 
\tNo more reason to hide.\033[0m""".split(' ')
    for l in text1:
        print(Fore.RED + l, end = ' ')
        time.sleep(0.35)
    
    print(Fore.BLUE + """
You hear the quiet but low voice from the other side of the door. Was it a good idea
to hide? Now you can only follow your decision and pray that the police will come fast.
You hear the loud noise of something hitting the door. Again. And again. He tries 
to break inside. A few moments later you hear the noise louder than anything else 
and the door flies open, hitting the wall. Through the bars in the closet door, you 
see a figure walking past the closet and going further into the room.\n""")
    
    #Make the intruder words scarier by timming them and making it say one word in 0.35 sec.
    txt_ = """-\033[1m Where you are, little rat?\033[0m""".split(' ')
    for j in txt_:
        print(Fore.RED + j, end = ' ')
        time.sleep(0.35)
    
    image2 = mpimg.imread("./_images/figure.png")
    plt.figure(figsize=(80,60))
    plt.axis('off')
    plt.imshow(image2)
    plt.show()
    
    time.sleep(0.3)
          
    print(Fore.BLUE + """
The figure in the black mask comes to your bed and looks under it. A few seconds
later it starts to look around the whole room. You try to breathe as quietly as 
possible, holding your breath at the time when the figure comes closer. You try not to
hold your breathing for too long so that later you won't make a loud sound trying 
to catch your breath. You see how the figure comes closer to the final place it
didn't look: the place you are hiding. You cover your mouth and nose with one hand
and lean harder against the wall.""")
    rand_choice_2 = np.random.randint(0,100)
    
    if rand_choice_2 > 10:
        print(Fore.BLUE + """\nThe sound of a police siren can be heard from afar. The figure turns
his head toward the window. Even from your place, you can feel his disappointment.
The intruder clicks his tongue and runs out of the room. You put your hand down and 
breathe in. You slowly get out of the room and move downstairs. You can see the
police cars in front of your house. You go to the door and open it right in time
for policemen to come. They started to ask questions, you try to explain to them and
say that the intruder just ran away, and they have a chance to catch him. Police
go to check your house. You sit on the stairs outside and cover your face with 
your hands. The only thought you have right now is a pray for them to catch the intruder
as fast as possible.

\033[1mENDING 2\033[0m""")
        
    else:
        print(Fore.BLUE + """\nSuddenly the door to the closet opens and the figure looks 
stright at you.\n""")
        
        #Make the intruder words scarier by timming them and making it say one word in 0.35 sec.
        txt = """-\033[1m There you are... Hide and Seek is over\033[0m.""".split(' ')
        for k in txt:
            print(Fore.RED + k, end = ' ')
            time.sleep(0.35)
        
        print(Fore.BLUE + """
You can swear that you heard a quiet laugh from the intruder.
He takes your hand and easily through you out of the wardrobe. You fell to the
floor and weren’t able to even move when you feel the pain at the back of your 
head and the world goes black.

You were found \033[1mdead\033[0m.""" + Fore.BLUE + """ Next time luck will be on your side.
Or maybe you should have done something else? 

\033[1mENDING 1\033[0m""")
    
#Defining the final function that will lead to the endings 3 and 4. The final result is randomized.
#Function describes 
#40% to get ending 4. 60% to get ending 3.
def fight():
    print(Fore.BLUE + """\nYou decide that the best way to defend is to attack first. 
You quickly lock the door and take the bat from the top shelf. You twist it in 
your hand to feel the weight and step closer to the wall at the side at which 
the door is opening. You hope to get the intruder by surprise and from a place 
he doesn't expect.
""" + Fore.BLUE + """
A few minutes later you hear quiet footsteps coming closer to the door. 
They stop right in front of your room. You see how the door handle starts to turn, 
but the door doesn't open as you just locked it.\n""")
    
    #Make the intruder words scarier by timming them and making it say one word in 0.35 sec.
    text0 = """-\033[1m There you are. Wanted to play hide and seek? No worries, I know you are there. 
\tNo more reason to hide.\033[0m""".split(' ')
    for i in text0:
        print(Fore.RED + i, end = ' ')
        time.sleep(0.35)
    
    image3 = mpimg.imread("./_images/door_room.png")
    plt.figure(figsize=(80,60))
    plt.axis('off')
    plt.imshow(image3)
    plt.show()
    
    time.sleep(0.3)
    
    print(Fore.BLUE + """
You hear the quiet but low voice from the other side of the door. Was it a good idea
to fight? Now you only can follow your decision and pray that you will be able 
to fight him long enough before the police come.""" + Fore.BLUE + """
You hear a loud noise, and the door shakes from something hitting the door. 
Again. And again. He tries to break inside... A few moments later you see how
the door flies open, hitting the wall right near your face and the figure of 
the huge man in the mask comes inside. He doesn't notice you yet. It's your chance!
You swing the bat and aim at his head.""")
    rand_choice_3 = np.random.randint(0,100)
    
    if rand_choice_3 > 40:
        print(Fore.BLUE + """\nYour hit gets to its goal and you hit the man in the head.
He was swayed by an unexpected attack and fell to the floor. You run out of the room,
go downstairs, and then outside the house, right in time when the police car stops
in front of your house. Adrenaline starts to fade and you understand how loud the
police sirens are. But it's not the time to think about it. You quickly tell the
policemen that you left an intruder upstairs, but you are unsure if he is 
conscious or not. Some of the policemen run upstairs, while you sit on the stairs
as you don't have any more energy.
""" + Fore.BLUE + """
5 minutes later one of them comes to you from upstairs and says that there is
no one upstairs. They were able to find stains of blood on the floor, but not
on the body. You cover your face with your hands and pray that they catch him as fast
as possible. Or even better if it's just a stupid nightmare...

ENDING 3""")
        
    else:
        print(Fore.BLUE + """\nUnfortunately, the intruder was fast enough to notice your 
movement. He dodges your attack and quickly catches your bat. With a strong grip,
he snatches it out of your hands.\n""")
        
        #Make the intruder words scarier by timming them and making it say one word in 0.35 sec.
        text = '-\033[1m Ho! Wanna play with me? Gladly!\033[0m'.split(' ')
        for n in text:
            print(Fore.RED + n, end = ' ')
            time.sleep(0.35)
        
        print(Fore.BLUE + """
\nYou try to move back, but he quickly gets closer to you. At the corner of your
eye, you see something sparkling in his hand and right after that, you feel a
strong pain in your stomach. You take a few steps back, hitting back against 
the wall, and look down. There is a knife in your stomach and your clothes start
to turn red. With shaking hands, you try to feel your stomach, but your vision becomes
blurry and you fall to the floor. The last thing you feel is the coldness of the floor 
and the low voice saying:\n""")
        
        #Make the intruder words scarier by timming them and making it say one word in 0.35 sec.
        text_ = '-\033[1m It was not a good idea to attack me. But at least you tried.\033[0m'.split(' ')
        for m in text_:
            print(Fore.RED + m, end = ' ')
            time.sleep(0.35)
        
        print(Fore.BLUE + """
\nYou \033[1mdied\033[0m.""" + Fore.BLUE + """ Next time luck will be on your side. Or maybe you should have done something else? 

\033[1mENDING 4\033[0m""")

                

#-----------------------------------------------------------------------------
#Additional functions.
               
#Define the failure function in case if player chooses the wrong path to go.
def fail():
    print(Fore.RED + "\n\033[1mYou died. That is unfortunate. Good luck next try and be more cautious!\033[0m")
    input('<Press enter to exit this try>\n')
    replay()
    
#Define the function for playing the music.
def music():
    display(Audio('./_music/horror_sound.wav', autoplay=True))

#Define the replay function that gives the chance to replay the game in case of failure.
def replay():
    replay_ = input('Do you want to try again? Yes/No ')
    if replay_.capitalize() == 'Yes' or replay_.capitalize() == 'Y':
        start()
    elif replay_.capitalize() == 'No' or replay_.capitalize() == 'N':
        print(Fore.GREEN + "That's sad. Well then. See you next time.")
    else:
        print(Fore.RED + "I don't have time to play with you. I'll take it as a no. See you next time")
    
#-----------------------------------------------------------------------------

#Start the game
start()
